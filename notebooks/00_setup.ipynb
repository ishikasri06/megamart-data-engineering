# %%
print("MegaMart Supermarket Data Engineering Project")
print("Databricks setup successful!")

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.supermarket;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.supermarket.raw_data;

# %%
# %sql
SHOW SCHEMAS IN workspace;

# %%
# %sql
SHOW VOLUMES IN workspace.supermarket;
